# %%
# The data set used in this example is from http://archive.ics.uci.edu/ml/datasets/Wine+Quality
# P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.

import os
import warnings
import sys

import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from urllib.parse import urlparse
import mlflow
from mlflow.models import infer_signature
import mlflow.sklearn

import logging

logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)


def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2


if __name__ == "__main__":
    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Read the wine-quality csv file from the URL
    csv_url = (
        "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-red.csv"
    )
    try:
        data = pd.read_csv(csv_url, sep=";")
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e
        )

    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]

    alpha =0.5# 0.5# float(sys.argv[1]) if len(sys.argv) > 1 else 0.5
    l1_ratio = 0.5#float(sys.argv[2]) if len(sys.argv) > 2 else 0.5

    with mlflow.start_run():
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        predicted_qualities = lr.predict(test_x)

        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        print("Elasticnet model (alpha={:f}, l1_ratio={:f}):".format(alpha, l1_ratio))
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)

        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)

        #predictions = lr.predict(train_x)
        #signature = infer_signature(train_x, predictions)

        ## For Remote server only(DAGShub)
        remote_server_uri="https://dagshub.com/erarunn/DVC.mlflow"
        #remote_server_uri="https://dagshub.com/krishnaik06/mlflowexperiments.mlflow"
        mlflow.set_tracking_uri(remote_server_uri)

        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme

        # Model registry does not work with file store
        if tracking_url_type_store != "file":
            # Register the model
            # There are other ways to use the Model Registry, which depends on the use case,
            # please refer to the doc for more information:
            # https://mlflow.org/docs/latest/model-registry.html#api-workflow
            mlflow.sklearn.log_model(
                lr, "model", registered_model_name="ElasticnetWineModel"
            )
        else:
            mlflow.sklearn.log_model(lr, "model")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[8], line 59
#      56 alpha =0.5# 0.5# float(sys.argv[1]) if len(sys.argv) > 1 else 0.5
#      57 l1_ratio = 0.5#float(sys.argv[2]) if len(sys.argv) > 2 else 0.5
# ---> 59 with mlflow.start_run():
#      60     lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
#      61     lr.fit(train_x, train_y)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\fluent.py:365, in start_run(run_id, experiment_id, run_name, nested, tags, description)
#     361         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     363     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 365     active_run_obj = client.create_run(
#     366         experiment_id=exp_id_for_run, tags=resolved_tags, run_name=run_name
#     367     )
#     369 _active_run_stack.append(ActiveRun(active_run_obj))
#     370 return _active_run_stack[-1]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\client.py:327, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     276 def create_run(
#     277     self,
#     278     experiment_id: str,
#    (...)
#     281     run_name: Optional[str] = None,
#     282 ) -> Run:
#     283     """
#     284     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     285     metrics, parameters, artifacts, etc.
#    (...)
#     325         status: RUNNING
#     326     """
# --> 327     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:131, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     126 # Extract user from tags
#     127 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     128 # in a later release.
#     129 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 131 return self.store.create_run(
#     132     experiment_id=experiment_id,
#     133     user_id=user_id,
#     134     start_time=start_time or get_current_time_millis(),
#     135     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     136     run_name=run_name,
#     137 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\store\tracking\rest_store.py:178, in RestStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     168 tag_protos = [tag.to_proto() for tag in tags]
#     169 req_body = message_to_json(
#     170     CreateRun(
#     171         experiment_id=str(experiment_id),
#    (...)
#     176     )
#     177 )
# --> 178 response_proto = self._call_endpoint(CreateRun, req_body)
#     179 return Run.from_proto(response_proto.run)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\store\tracking\rest_store.py:59, in RestStore._call_endpoint(self, api, json_body)
#      57 endpoint, method = _METHOD_TO_INFO[api]
#      58 response_proto = api.Response()
# ---> 59 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\utils\rest_utils.py:202, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     200     call_kwargs["json"] = json_body
#     201     response = http_request(**call_kwargs)
# --> 202 response = verify_rest_response(response, endpoint)
#     203 js_dict = json.loads(response.text)
#     204 parse_dict(js_dict=js_dict, message=response_proto)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\utils\rest_utils.py:140, in verify_rest_response(response, endpoint)
#     135     else:
#     136         base_msg = (
#     137             f"API request to endpoint {endpoint} "
#     138             f"failed with error code {response.status_code} != 200"
#     139         )
# --> 140         raise MlflowException(
#     141             f"{base_msg}. Response body: '{response.text}'",
#     142             error_code=get_error_code(response.status_code),
#     143         )
#     145 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     146 # response
#     147 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 403 != 200. Response body: ''

# %%
# !pip3 install dagshub --upgrade
# Out:
# Collecting dagshub
#   Obtaining dependency information for dagshub from https://files.pythonhosted.org/packages/23/7a/9b4e19031d63e60a69551e468aa3bf68d3a3ced608844836ffad44fa5e18/dagshub-0.3.8.post1-py3-none-any.whl.metadata
#   Downloading dagshub-0.3.8.post1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: PyYAML>=5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dagshub) (6.0.1)
# Collecting fusepy>=3 (from dagshub)
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting appdirs>=1.4.4 (from dagshub)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: click>=8.0.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dagshub) (8.1.7)
# Collecting httpx~=0.23.0 (from dagshub)
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#      ---------------------------------------- 71.5/71.5 kB ? eta 0:00:00
# Requirement already satisfied: GitPython>=3.1.29 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dagshub) (3.1.37)
# Collecting rich[jupyter]~=13.1.0 (from dagshub)
#   Downloading rich-13.1.0-py3-none-any.whl (238 kB)
#      ---------------------------------------- 0.0/238.4 kB ? eta -:--:--
#      -------------------------------------- 238.4/238.4 kB 7.4 MB/s eta 0:00:00
# Collecting dacite~=1.6.0 (from dagshub)
#   Downloading dacite-1.6.0-py3-none-any.whl (12 kB)
# Collecting tenacity~=8.2.2 (from dagshub)
#   Obtaining dependency information for tenacity~=8.2.2 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting gql[requests] (from dagshub)
#   Downloading gql-3.4.1-py2.py3-none-any.whl (65 kB)
#      ---------------------------------------- 0.0/65.1 kB ? eta -:--:--
#      ---------------------------------------- 65.1/65.1 kB ? eta 0:00:00
# Collecting dataclasses-json (from dagshub)
#   Obtaining dependency information for dataclasses-json from https://files.pythonhosted.org/packages/21/1f/1cff009cff64420572b9f75b70e4a054095719179a172297dfdd65843162/dataclasses_json-0.6.1-py3-none-any.whl.metadata
#   Downloading dataclasses_json-0.6.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dagshub) (2.1.1)
# Collecting treelib~=1.6.4 (from dagshub)
#   Downloading treelib-1.6.4-py3-none-any.whl (18 kB)
# Collecting pathvalidate~=3.0.0 (from dagshub)
#   Obtaining dependency information for pathvalidate~=3.0.0 from https://files.pythonhosted.org/packages/8e/3f/405eedc699cea7ef0b49c04966701316f63b60ffa49e9dc6bbce5480cae7/pathvalidate-3.0.0-py3-none-any.whl.metadata
#   Downloading pathvalidate-3.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dagshub) (2.8.2)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from click>=8.0.4->dagshub) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from GitPython>=3.1.29->dagshub) (4.0.10)
# Requirement already satisfied: certifi in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx~=0.23.0->dagshub) (2023.7.22)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx~=0.23.0->dagshub)
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ---------------------------------------- 0.0/69.6 kB ? eta -:--:--
#      ---------------------------------------- 69.6/69.6 kB 3.7 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3 (from httpx~=0.23.0->dagshub)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx~=0.23.0->dagshub) (1.3.0)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich[jupyter]~=13.1.0->dagshub)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ---------------------------------------- 0.0/51.1 kB ? eta -:--:--
#      ---------------------------------------- 51.1/51.1 kB ? eta 0:00:00
# Collecting ipywidgets<8.0.0,>=7.5.1 (from rich[jupyter]~=13.1.0->dagshub)
#   Obtaining dependency information for ipywidgets<8.0.0,>=7.5.1 from https://files.pythonhosted.org/packages/14/3f/fa7fcf85061819f5a10ed09eaef38fe97d0f3f91d14674bbb26c3fc2a622/ipywidgets-7.8.1-py2.py3-none-any.whl.metadata
#   Downloading ipywidgets-7.8.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from rich[jupyter]~=13.1.0->dagshub) (2.16.1)
# Requirement already satisfied: six in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from treelib~=1.6.4->dagshub) (1.16.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->dagshub)
#   Obtaining dependency information for marshmallow<4.0.0,>=3.18.0 from https://files.pythonhosted.org/packages/ed/3c/cebfdcad015240014ff08b883d1c0c427f2ba45ae8c6572851b6ef136cad/marshmallow-3.20.1-py3-none-any.whl.metadata
#   Downloading marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->dagshub)
#   Obtaining dependency information for typing-inspect<1,>=0.4.0 from https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl.metadata
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting graphql-core<3.3,>=3.2 (from gql[requests]->dagshub)
#   Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#      ---------------------------------------- 0.0/202.9 kB ? eta -:--:--
#      ------------------------------------- 202.9/202.9 kB 12.8 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.6 (from gql[requests]->dagshub)
#   Using cached yarl-1.9.2-cp311-cp311-win_amd64.whl (60 kB)
# Collecting backoff<3.0,>=1.11.1 (from gql[requests]->dagshub)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests<3,>=2.26 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gql[requests]->dagshub) (2.31.0)
# Collecting requests-toolbelt<1,>=0.9.1 (from gql[requests]->dagshub)
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#      ---------------------------------------- 54.5/54.5 kB ? eta 0:00:00
# Requirement already satisfied: urllib3<2,>=1.26 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gql[requests]->dagshub) (1.26.16)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas->dagshub) (1.24.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas->dagshub) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas->dagshub) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.29->dagshub) (5.0.1)
# Collecting h11<0.15,>=0.13 (from httpcore<0.17.0,>=0.15.0->httpx~=0.23.0->dagshub)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx~=0.23.0->dagshub) (3.7.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.1.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.9.0)
# Collecting widgetsnbextension~=3.6.6 (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub)
#   Obtaining dependency information for widgetsnbextension~=3.6.6 from https://files.pythonhosted.org/packages/9c/a0/ba2634cd75b7d7f8f9aeb38edf854cd6c9877ec064013a62630b4541b88f/widgetsnbextension-3.6.6-py2.py3-none-any.whl.metadata
#   Downloading widgetsnbextension-3.6.6-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (8.14.0)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub)
#   Obtaining dependency information for jupyterlab-widgets<3,>=1.0.0 from https://files.pythonhosted.org/packages/06/c9/50a16b6e7410d661ea16160f8c650c444ab83740b437b3c202ca7d8e2b73/jupyterlab_widgets-1.1.7-py3-none-any.whl.metadata
#   Downloading jupyterlab_widgets-1.1.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->dagshub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.26->gql[requests]->dagshub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.26->gql[requests]->dagshub) (3.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub) (4.5.0)
# Collecting multidict>=4.0 (from yarl<2.0,>=1.6->gql[requests]->dagshub)
#   Using cached multidict-6.0.4-cp311-cp311-win_amd64.whl (28 kB)
# Requirement already satisfied: backcall in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.0)
# Requirement already satisfied: decorator in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.0.39)
# Requirement already satisfied: stack-data in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.6.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (7.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.7.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.24.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.0.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.3.3)
# Requirement already satisfied: wcwidth in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.2)
# Requirement already satisfied: argon2-cffi in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (23.1.0)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (7.7.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.9.2)
# Requirement already satisfied: overrides in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.17.1)
# Requirement already satisfied: pywinpty in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.0.11)
# Requirement already satisfied: pyzmq>=24 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.6.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.25.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.9.14)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.9.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (306)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.0.0)
# Requirement already satisfied: defusedxml in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.18.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.6.7.post1)
# Requirement already satisfied: nest-asyncio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.5.7)
# Requirement already satisfied: psutil in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.9.5)
# Requirement already satisfied: webencodings in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.4)
# Requirement already satisfied: uri-template in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.4.1)
# Requirement already satisfied: pycparser in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.2.3)
# Downloading dagshub-0.3.8.post1-py3-none-any.whl (182 kB)
#    ---------------------------------------- 0.0/182.4 kB ? eta -:--:--
#    ----------------------------------- ---- 163.8/182.4 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 182.4/182.4 kB 3.7 MB/s eta 0:00:00
# Downloading pathvalidate-3.0.0-py3-none-any.whl (21 kB)
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading dataclasses_json-0.6.1-py3-none-any.whl (27 kB)
# Downloading ipywidgets-7.8.1-py2.py3-none-any.whl (124 kB)
#    ---------------------------------------- 0.0/124.2 kB ? eta -:--:--
#    ---------------------------------------- 124.2/124.2 kB 7.6 MB/s eta 0:00:00
# Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.4 kB ? eta -:--:--
#    ---------------------------------------- 49.4/49.4 kB ? eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading jupyterlab_widgets-1.1.7-py3-none-any.whl (295 kB)
#    ---------------------------------------- 0.0/295.4 kB ? eta -:--:--
#    -------------------------------------- - 286.7/295.4 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 295.4/295.4 kB 4.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-3.6.6-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.6 MB 9.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.9/1.6 MB 9.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 7.8 MB/s eta 0:00:00
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=0739ec82d1e79c81e37ada5ff7bd76b8e7e60813fa42d6eff52e7e10a73eced4
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\db\4a\86\fdda91f8b8ebb0a70e4181dc2423b1f70c3c2d3bd1158685b5
# Successfully built fusepy
# Installing collected packages: rfc3986, fusepy, commonmark, appdirs, treelib, tenacity, rich, pathvalidate, mypy-extensions, multidict, marshmallow, jupyterlab-widgets, h11, graphql-core, dacite, backoff, yarl, typing-inspect, requests-toolbelt, httpcore, httpx, gql, dataclasses-json, widgetsnbextension, ipywidgets, dagshub
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.8
#     Uninstalling jupyterlab-widgets-3.0.8:
#       Successfully uninstalled jupyterlab-widgets-3.0.8
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.8
#     Uninstalling widgetsnbextension-4.0.8:
#       Successfully uninstalled widgetsnbextension-4.0.8
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.1.0
#     Uninstalling ipywidgets-8.1.0:
#       Successfully uninstalled ipywidgets-8.1.0
# Successfully installed appdirs-1.4.4 backoff-2.2.1 commonmark-0.9.1 dacite-1.6.0 dagshub-0.3.8.post1 dataclasses-json-0.6.1 fusepy-3.0.1 gql-3.4.1 graphql-core-3.2.3 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 ipywidgets-7.8.1 jupyterlab-widgets-1.1.7 marshmallow-3.20.1 multidict-6.0.4 mypy-extensions-1.0.0 pathvalidate-3.0.0 requests-toolbelt-0.10.1 rfc3986-1.5.0 rich-13.1.0 tenacity-8.2.3 treelib-1.6.4 typing-inspect-0.9.0 widgetsnbextension-3.6.6 yarl-1.9.2

# %%
dagshub
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dagshub
#
# NameError: name 'dagshub' is not defined
